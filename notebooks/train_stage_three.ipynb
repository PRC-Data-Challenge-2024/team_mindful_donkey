# %%
import h2o
from h2o.automl import H2OAutoML

import pandas as pd
import numpy as np

import matplotlib as plt
# %matplotlib inline

#Import the Estimators
from h2o.estimators.deeplearning import H2ODeepLearningEstimator
from h2o.estimators import H2OXGBoostEstimator

#Import h2o grid search 
import h2o.grid 
from h2o.grid.grid_search import H2OGridSearch

import glob

# %%
h2o.init(max_mem_size = "40g", nthreads = 11)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# Warning: Your H2O cluster version is (3 months and 14 days) old.  There may be a newer version available.
# Please download and install the latest version from: https://h2o-release.s3.amazonaws.com/h2o/latest_stable.html
# --------------------------  -----------------------------
# H2O_cluster_uptime:         16 hours 43 mins
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.46.0.4
# H2O_cluster_version_age:    3 months and 14 days
# H2O_cluster_name:           H2O_from_python_mark_keph72
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    37.32 Gb
# H2O_cluster_total_cores:    128
# H2O_cluster_allowed_cores:  11
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.11.0 final
# --------------------------  -----------------------------

# %%
data = h2o.import_file("data/STAGE_3_TRAIN.csv")
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
x = data.columns
y = "tow"
ignore = ["flight_id", "dataset"] 
## add adep and ades?
x = list(set(x) - set(ignore))
x.remove(y)
print(x)

data["aircraft_type"] = data["aircraft_type"].asfactor()
# Out:
# ['stage_two_500', 'alt_per_s', 'stage_one', 'stage_two_700', 'stage_two_400', 'time_to_cruise', 'stage_two_1000', 'percent_error', 'aircraft_type', 'stage_two_300', 'stage_two_200', 'stage_two_800', 'stage_two_900', 'stage_two_100', 'stage_two_600', 'first_cruise_alt']

# %%
test, train = data.split_frame(ratios = [0.05], seed = 26)
print(len(train))
# Out:
# 350583

# %%
aml = H2OAutoML(max_models=50, seed=75, verbosity="info", stopping_metric="RMSE")
aml.train(x=x, y=y, training_frame=train)
# Out:
# AutoML progress: |
# 18:57:00.337: Project: AutoML_4_20241024_185700
# 18:57:00.338: 5-fold cross-validation will be used.
# 18:57:00.338: Setting stopping tolerance adaptively based on the training frame: 0.0016889024802299066
# 18:57:00.338: Build control seed: 75
# 18:57:00.339: training frame: Frame key: AutoML_4_20241024_185700_training_py_8_sid_bf4d    cols: 19    rows: 350583  chunks: 512    size: 39171491  checksum: 626891403074473263
# 18:57:00.339: validation frame: NULL
# 18:57:00.339: leaderboard frame: NULL
# 18:57:00.339: blending frame: NULL
# 18:57:00.340: response column: tow
# 18:57:00.340: fold column: null
# 18:57:00.340: weights column: null
# 18:57:00.341: Loading execution steps: [{XGBoost : [def_2 (1g, 10w), def_1 (2g, 10w), def_3 (3g, 10w), grid_1 (4g, 90w), lr_search (7g, 30w)]}, {GLM : [def_1 (1g, 10w)]}, {DRF : [def_1 (2g, 10w), XRT (3g, 10w)]}, {GBM : [def_5 (1g, 10w), def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w), def_1 (3g, 10w), grid_1 (4g, 60w), lr_annealing (7g, 10w)]}, {DeepLearning : [def_1 (3g, 10w), grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {completion : [resume_best_grids (6g, 60w)]}, {StackedEnsemble : [monotonic (9g, 10w), best_of_family_xglm (10g, 10w), all_xglm (10g, 10w)]}]
# 18:57:00.344: AutoML job created: 2024.10.24 18:57:00.336
# 18:57:00.346: AutoML build started: 2024.10.24 18:57:00.345
# 18:57:00.348: AutoML: starting XGBoost_1_AutoML_4_20241024_185700 model training
#
# ██
# 18:59:45.672: New leader: XGBoost_1_AutoML_4_20241024_185700, rmse: 2136.740689722515
# 18:59:45.674: AutoML: starting GLM_1_AutoML_4_20241024_185700 model training
#
#
# 18:59:48.727: AutoML: starting GBM_1_AutoML_4_20241024_185700 model training
#
# ████████████████
# 19:02:01.912: New leader: GBM_1_AutoML_4_20241024_185700, rmse: 1946.3943934127378
# 19:02:01.913: AutoML: starting XGBoost_2_AutoML_4_20241024_185700 model training
#
# ████████████
# 19:03:52.995: AutoML: starting DRF_1_AutoML_4_20241024_185700 model training
#
# ████████████████████████████████
# 19:22:54.86: AutoML: starting GBM_2_AutoML_4_20241024_185700 model training
#
#
# 19:24:22.727: AutoML: starting GBM_3_AutoML_4_20241024_185700 model training
#
#
# 19:25:39.254: AutoML: starting GBM_4_AutoML_4_20241024_185700 model training
#
#
# 19:26:58.503: New leader: GBM_4_AutoML_4_20241024_185700, rmse: 1946.0888206181594
# 19:26:58.506: AutoML: starting XGBoost_3_AutoML_4_20241024_185700 model training
#
#
# 19:32:17.255: AutoML: starting XRT_1_AutoML_4_20241024_185700 model training
#
#
# 19:49:37.160: AutoML: starting GBM_5_AutoML_4_20241024_185700 model training
#
#
# 19:51:23.359: AutoML: starting DeepLearning_1_AutoML_4_20241024_185700 model training
#
# █
# 19:52:57.263: AutoML: starting XGBoost_grid_1_AutoML_4_20241024_185700 hyperparameter search
# 21:55:05.703: AutoML: starting GBM_grid_1_AutoML_4_20241024_185700 hyperparameter search
#
#
# 22:00:05.886: New leader: GBM_grid_1_AutoML_4_20241024_185700_model_3, rmse: 1933.2147547833722
# 22:16:39.723: AutoML: starting DeepLearning_grid_1_AutoML_4_20241024_185700 hyperparameter search
#
#
# 22:42:04.205: AutoML: starting DeepLearning_grid_2_AutoML_4_20241024_185700 hyperparameter search
#
#
# 22:57:56.226: AutoML: starting DeepLearning_grid_3_AutoML_4_20241024_185700 hyperparameter search
#
#
# 23:14:04.976: No base models, due to timeouts or the exclude_algos option. Skipping StackedEnsemble 'monotonic'.
# 23:14:04.981: AutoML: starting StackedEnsemble_BestOfFamily_1_AutoML_4_20241024_185700 model training
#
#
# 23:14:13.392: New leader: StackedEnsemble_BestOfFamily_1_AutoML_4_20241024_185700, rmse: 1925.124662753439
# 23:14:13.396: AutoML: starting StackedEnsemble_AllModels_1_AutoML_4_20241024_185700 model training
#
# | (done) 100%
#
# 23:14:44.949: New leader: StackedEnsemble_AllModels_1_AutoML_4_20241024_185700, rmse: 1909.0742400463419
# 23:14:44.950: Actual modeling steps: [{XGBoost : [def_2 (1g, 10w)]}, {GLM : [def_1 (1g, 10w)]}, {GBM : [def_5 (1g, 10w)]}, {XGBoost : [def_1 (2g, 10w)]}, {DRF : [def_1 (2g, 10w)]}, {GBM : [def_2 (2g, 10w), def_3 (2g, 10w), def_4 (2g, 10w)]}, {XGBoost : [def_3 (3g, 10w)]}, {DRF : [XRT (3g, 10w)]}, {GBM : [def_1 (3g, 10w)]}, {DeepLearning : [def_1 (3g, 10w)]}, {XGBoost : [grid_1 (4g, 90w)]}, {GBM : [grid_1 (4g, 60w)]}, {DeepLearning : [grid_1 (4g, 30w), grid_2 (5g, 30w), grid_3 (5g, 30w)]}, {StackedEnsemble : [best_of_family_xglm (10g, 10w), all_xglm (10g, 10w)]}]
# 23:14:44.951: AutoML build stopped: 2024.10.24 23:14:44.950
# 23:14:44.951: AutoML build done: built 50 models
# 23:14:44.952: AutoML duration:  4:17:44.605
# Model Details
# =============
# H2OStackedEnsembleEstimator : Stacked Ensemble
# Model Key: StackedEnsemble_AllModels_1_AutoML_4_20241024_185700
#
#
# Model Summary for Stacked Ensemble:
# key                                        value
# -----------------------------------------  ----------------
# Stacking strategy                          cross_validation
# Number of base models (used / total)       27/50
# # GBM base models (used / total)           11/15
# # XGBoost base models (used / total)       13/18
# # DRF base models (used / total)           2/2
# # DeepLearning base models (used / total)  1/14
# # GLM base models (used / total)           0/1
# Metalearner algorithm                      GLM
# Metalearner fold assignment scheme         Random
# Metalearner nfolds                         5
# Metalearner fold_column
# Custom metalearner hyperparameters         None
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on train data. **
#
# MSE: 2047541.6352718654
# RMSE: 1430.923350592849
# MAE: 990.9448416277509
# RMSLE: 0.019274823919480613
# Mean Residual Deviance: 2047541.6352718654
# R^2: 0.9992868292996597
# Null degrees of freedom: 9854
# Residual degrees of freedom: 9827
# Null deviance: 28294280824166.977
# Residual deviance: 20178522815.604233
# AIC: 171239.62096912888
#
# ModelMetricsRegressionGLM: stackedensemble
# ** Reported on cross-validation data. **
#
# MSE: 3644564.4540085173
# RMSE: 1909.0742400463419
# MAE: 1238.4488037532806
# RMSLE: 0.02287431818553398
# Mean Residual Deviance: 3644564.4540085173
# R^2: 0.9987147756735077
# Null degrees of freedom: 350582
# Residual degrees of freedom: 350555
# Null deviance: 994167515024325.2
# Residual deviance: 1277722339979.668
# AIC: 6291839.454047062
#
# Cross-Validation Metrics Summary:
#                         mean         sd           cv_1_valid    cv_2_valid    cv_3_valid    cv_4_valid    cv_5_valid
# ----------------------  -----------  -----------  ------------  ------------  ------------  ------------  ------------
# aic                     1.25841e+06  2247.3       1.2607e+06    1.25741e+06   1.25957e+06   1.25499e+06   1.25939e+06
# loglikelihood           0            0            0             0             0             0             0
# mae                     1238.45      3.33806      1238.24       1233.33       1240.22       1242.34       1238.13
# mean_residual_deviance  3.64462e+06  37412.3      3.62862e+06   3.60885e+06   3.63975e+06   3.70783e+06   3.63803e+06
# mse                     3.64462e+06  37412.3      3.62862e+06   3.60885e+06   3.63975e+06   3.70783e+06   3.63803e+06
# null_deviance           1.98834e+14  1.46074e+12  1.98948e+14   2.00419e+14   1.99596e+14   1.96508e+14   1.98696e+14
# r2                      0.998715     2.03377e-05  0.998718      0.998738      0.99872       0.998682      0.998715
# residual_deviance       2.55544e+11  2.18672e+09  2.5495e+11    2.52977e+11   2.5546e+11    2.59026e+11   2.5531e+11
# rmse                    1909.07      9.77449      1904.89       1899.7        1907.81       1925.57       1907.36
# rmsle                   0.0228743    4.75212e-05  0.0228575     0.0229489     0.0228182     0.0228693     0.0228776
#
# [tips]
# Use `model.explain()` to inspect the model.
# --
# Use `h2o.display.toggle_user_tips()` to switch on/off this section.

# %%
leader_model = aml.leader
print(round(leader_model.rmse(), 0))
#print(round(leader_model.rmse(valid=True), 0))
print(round(leader_model.model_performance(test).rmse(), 0))
# Out:
# 1431.0
# 2440.0

# %%
# 1531.0
# 2398.0

# %%
## Save ensemble
from datetime import datetime
now = datetime.now()
h2o.save_model(model=leader_model, path="data/models/stage_three_"+now.strftime("%m_%d_%y_%H_%M")+"_added", force=True)
# Out:
# '/home/mark/prc_challenge/data/models/stage_three_10_27_24_17_53_added/StackedEnsemble_AllModels_1_AutoML_4_20241024_185700'

# %% [markdown]
# ## RUN STAGE THREE SUBMISSION

# %%
data = h2o.import_file("data/STAGE_3_TEST.csv")
data
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
#   flight_id    tow  dataset       first_cruise_alt    time_to_cruise    alt_per_s    stage_one    stage_two_100    stage_two_200    stage_two_300    stage_two_400    stage_two_500    stage_two_600    stage_two_700    stage_two_800    stage_two_900    stage_two_1000  aircraft_type      percent_error
# -----------  -----  ----------  ------------------  ----------------  -----------  -----------  ---------------  ---------------  ---------------  ---------------  ---------------  ---------------  ---------------  ---------------  ---------------  ----------------  ---------------  ---------------
# 2.48754e+08    nan  submission               36000              1350         26.7      69933.1          66052.3          65215.9          65550.8          66918            67455.6          67808.1          68133.6          67882.2          68597.9           69366.9  B738                     4.97785
# 2.48754e+08    nan  submission               36000              2070         17.4     214816           210956           204897           214594           226919           223442           223662           227598           222790           225984            224391    A333                     5.94711
# 2.48754e+08    nan  submission                 nan               nan        nan       222549           255834           272244           238921           256087           252095           263190           257855           257676           270981            274112    B77W                    11.4072
# 2.48764e+08    nan  submission               35000              1260         27.8      64158.6            nan              nan              nan              nan              nan              nan              nan              nan              nan               nan    B738                     4.97785
# 2.48764e+08    nan  submission               31000              1530         20.3      50340.6            nan              nan              nan              nan              nan              nan              nan              nan              nan               nan    BCS3                     3.9136
# 2.48758e+08    nan  submission               39000              1470         26.5      65195.3          62720.2          65163.7          64612.2          66064.8          65112.5          67573.4          64976.5          65861.4          65940             64604.6  B38M                     4.35642
# 2.48764e+08    nan  submission               37000              1530         24.2      63873            59431.6          58813.4          59139.5          60372.6          60774.5          60452            61539.4          62588.2          61772.7           60045.3  A320                     6.07218
# 2.48755e+08    nan  submission               31000               930         33.3      58110.7          64634.7          64159.6          64267.8          59497            58922.1          58212.6          57819.5          58202.6          58121.8             nan    B738                     4.97785
# 2.48754e+08    nan  submission               32000              1050         30.5      56218.5          57613.1          58116.2          57592            60816.7          61158.3          60158.4          59105.6          58081.1          58329             57861.5  A320                     6.07218
# 2.48754e+08    nan  submission               36000              1470         24.5      45610.8            nan              nan              nan              nan              nan              nan              nan              nan              nan               nan    E190                     3.11874
# [158149 rows x 19 columns]

# %%
data["aircraft_type"] = data["aircraft_type"].asfactor()

# %%
submission_set = pd.read_csv("/mnt/SMB_share/mark/flight_competition/final_submission_set.csv")
submission_set
# Out:
#         flight_id        date                          callsign  adep  \
# 0       248753821  2022-01-01  3b3de0f3ad0ee192513995c02f7bf7cf  LTFJ
# 1       248753822  2022-01-01  e06dd03d4a879ca37d9e18c1bd7cad16  EBBR
# 2       248754498  2022-01-01  2d3b1c962c78c4ebeef11bcd51b9e94c  KMIA
# 3       248763650  2022-01-01  35f7721f68bf85128195547ae38b0f04  EBBR
# 4       248763651  2022-01-01  eb56918bee9bc5204624186b9bcc4391  LSZH
# ...           ...         ...                               ...   ...
# 158144  258068876  2022-12-31  c9fca302ca2e28acab0eb0bb1b46f11b  LTFM
# 158145  258064675  2022-12-31  00f96ad0e382476649574ba044c764fc  EHAM
# 158146  258065436  2022-12-31  87c552b7f6d9bbd16a66e95df761c7f2  LEBL
# 158147  258058138  2022-12-31  2cd57e434494606c965bac87c024bda2  LIPE
# 158148  258058370  2022-12-31  5f0c222c7f7ceff3fbe75c854cce74c9  UBBB
#
#                      name_adep country_code_adep  ades  \
# 0       Istanbul Sabiha Gokcen                TR  LFLL
# 1                     Brussels                BE  KJFK
# 2                        Miami                US  EGLL
# 3                     Brussels                BE  LEAL
# 4                       Zurich                CH  LFPG
# ...                        ...               ...   ...
# 158144            iGA Istanbul                TR  LSZH
# 158145               Amsterdam                NL  EDDF
# 158146               Barcelona                ES  KJFK
# 158147                 Bologna                IT  LOWW
# 158148                    Baku                AZ  LTFM
#
#                       name_ades country_code_ades  actual_offblock_time  \
# 0                          Lyon                FR  2022-01-01T09:44:00Z
# 1                  New York JFK                US  2022-01-01T09:45:00Z
# 2               London Heathrow                GB  2022-01-01T01:52:00Z
# 3                      Alicante                ES  2022-01-01T12:02:00Z
# 4       Paris Charles de Gaulle                FR  2022-01-01T12:03:00Z
# ...                         ...               ...                   ...
# 158144                   Zurich                CH  2022-12-31T09:25:00Z
# 158145                Frankfurt                DE  2022-12-31T10:04:21Z
# 158146             New York JFK                US  2022-12-31T09:34:00Z
# 158147                   Vienna                AT  2022-12-31T09:37:00Z
# 158148             iGA Istanbul                TR  2022-12-31T09:40:00Z
#
#                 arrival_time aircraft_type wtc  \
# 0       2022-01-01T12:48:33Z          B738   M
# 1       2022-01-01T17:49:51Z          A333   H
# 2       2022-01-01T09:55:16Z          B77W   H
# 3       2022-01-01T14:13:56Z          B738   M
# 4       2022-01-01T13:09:44Z          BCS3   M
# ...                      ...           ...  ..
# 158144  2022-12-31T12:24:24Z          A321   M
# 158145  2022-12-31T10:55:35Z          A320   M
# 158146  2022-12-31T17:51:22Z          B772   H
# 158147  2022-12-31T10:47:00Z          E195   M
# 158148  2022-12-31T12:28:00Z          B738   M
#
#                                  airline  flight_duration  taxiout_time  \
# 0       6351ec1b849adacc0cbb3b1313d8d39b              170            15
# 1       bdeeef3a675587d530de70a25d7118d2              470            15
# 2       5543e4dc327359ffaf5b9c0e6faaf0e1              473            10
# 3       f53c55b5cf0cbb3be755bf50df6fa52d              123             9
# 4       2d5def0a5a844b343ba1b7cc9cb28fa9               56            11
# ...                                  ...              ...           ...
# 158144  6351ec1b849adacc0cbb3b1313d8d39b              154            25
# 158145  f502877cab405652cf0dd70c2213e730               42             9
# 158146  5543e4dc327359ffaf5b9c0e6faaf0e1              483            14
# 158147  5d407cb11cc29578cc3e292e743f5393               55            15
# 158148  6351ec1b849adacc0cbb3b1313d8d39b              158            10
#
#         flown_distance  tow
# 0                 1122  NaN
# 1                 3205  NaN
# 2                 3965  NaN
# 3                  802  NaN
# 4                  292  NaN
# ...                ...  ...
# 158144             988  NaN
# 158145             240  NaN
# 158146            3426  NaN
# 158147             335  NaN
# 158148            1014  NaN
#
# [158149 rows x 18 columns]

# %%
this_model = glob.glob("/home/mark/prc_challenge/data/models/stage_three_10_27_24_17_53_added/*")[0]
stage_three_model = h2o.load_model(this_model)
now = datetime.now()

predictions = stage_three_model.predict(data)
print("data loaded")
data = data[["flight_id"]]
data["tow"] = predictions
data.as_data_frame().to_csv("data/STAGE_3_SUBMISSION_PREDICTIONS.csv", index=False)
data.as_data_frame()[["flight_id", "tow"]].to_csv("data/submission_predictions_"+now.strftime("%m_%d_%y_%H_%M")+".csv", index=False)
data
# Out:
# stackedensemble prediction progress: |███████████████████████████████████████████| (done) 100%
# data loaded
# /home/mark/for_pycaret/lib/python3.11/site-packages/h2o/frame.py:1981: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
# /home/mark/for_pycaret/lib/python3.11/site-packages/h2o/frame.py:1981: H2ODependencyWarning: Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using multi-thread, install polars and pyarrow and use it as pandas_df = h2o_df.as_data_frame(use_multi_thread=True)
#
#   warnings.warn("Converting H2O frame to pandas dataframe using single-thread.  For faster conversion using"
#   flight_id       tow
# -----------  --------
# 2.48754e+08   69946.1
# 2.48754e+08  217670
# 2.48754e+08  225983
# 2.48764e+08   64393.3
# 2.48764e+08   50188.8
# 2.48758e+08   65032.8
# 2.48764e+08   63407.8
# 2.48755e+08   57563.9
# 2.48754e+08   53713.4
# 2.48754e+08   45520.8
# [158149 rows x 2 columns]

# %%
## Add next closest airport?

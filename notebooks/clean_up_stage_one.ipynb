# %%
import pandas as pd
import numpy as np
import datetime

from pytz import country_timezones
import pytz

import glob

import airportsdata

import geopandas as gpd

from shapely.ops import nearest_points

# %%
from tqdm import tqdm
tqdm.pandas()

# %% [markdown]
# ## Combine chunks

# %%
chunk_files = glob.glob("data/chunks/*")
traject_files = [file for file in chunk_files if "traject_all_rerun" in file]
characteristics_files = [file for file in chunk_files if "characteristics_all_rerun" in file]
print(len(characteristics_files))
# Out:
# 300

# %%
ch_df_array = []
for file in characteristics_files: 
    df = pd.read_csv(file)
    ch_df_array.append(df) 

all_char = pd.concat(ch_df_array)
all_char
# Out:
#       flight_id     max_fuel               first_cruise  first_cruise_alt
# 0     254942095  5786.875688  2022-09-01 17:29:30+00:00           37000.0
# 1     254942148  3516.894652  2022-09-01 17:47:30+00:00           34000.0
# 2     254942098  1848.781798  2022-09-01 17:27:00+00:00           30000.0
# 3     254942161  4449.149948  2022-09-01 17:33:00+00:00           37000.0
# 4     254942068  9767.098354  2022-09-01 17:50:30+00:00           35000.0
# ...         ...          ...                        ...               ...
# 1752  257010801  3943.376975  2022-11-14 19:34:30+00:00           35000.0
# 1753  257010770  2255.845093  2022-11-14 19:24:00+00:00           36000.0
# 1754  257010761  2284.443142                        NaN               NaN
# 1755  257010948  4218.414258  2022-11-14 19:49:30+00:00           35000.0
# 1756  256991474  7145.044933  2022-11-14 05:51:30+00:00           35000.0
#
# [510865 rows x 4 columns]

# %%
all_char.to_csv("data/trajectory_characteristics.csv", index=False)

# %% [markdown]
# ## Load and clean up data

# %%
data = pd.read_csv("data/datasets_with_regression.csv")
data.head()
# Out:
#    flight_id        date                          callsign  adep  \
# 0  248763780  2022-01-01  3840d84f25d3f5fcc0a1be3076bb4039  EGLL
# 1  248760618  2022-01-01  f6f610e73002b8892a239a81321f7f1d  LEBL
# 2  248753824  2022-01-01  139670936660762c230ca92556ba842b  ESSA
# 3  248753852  2022-01-01  509dc61bb54fbab0e5406067c95603e2  LSZH
# 4  248755934  2022-01-01  d0610d000dcf26b1d7bba8103ecc393d  EIDW
#
#            name_adep country_code_adep  ades        name_ades  \
# 0    London Heathrow                GB  EICK             Cork
# 1          Barcelona                ES  KMIA            Miami
# 2  Stockholm Arlanda                SE  KORD   Chicago O'Hare
# 3             Zurich                CH  KPHL     Philadelphia
# 4             Dublin                IE  EGLL  London Heathrow
#
#   country_code_ades  actual_offblock_time  ... flown_distance            tow  \
# 0                IE  2022-01-01T13:46:00Z  ...            321   54748.000000
# 1                US  2022-01-01T09:55:00Z  ...           4193  185441.000000
# 2                US  2022-01-01T09:39:00Z  ...           3770  230396.000000
# 3                US  2022-01-01T11:04:00Z  ...           3607  157615.000000
# 4                GB  2022-01-01T12:36:00Z  ...            305   70318.447226
#
#      dataset great_circle_miles  mtow_fill  oew_fill  total_fuel  replacer  \
# 0  challenge         345.260072    78000.0   42600.0      2057.0      A320
# 1  challenge        4688.045888   297000.0  138000.0         NaN      A333
# 2  challenge        4260.121521   242000.0  122780.0         NaN      A333
# 3  challenge        4013.989694   228000.0  119000.0         NaN      A332
# 4  challenge         279.504141    97000.0   50000.0         NaN      A321
#
#   total_fuel_regression  total_fuel_fill
# 0           2079.383478      2057.000000
# 1          70057.306105     70057.306105
# 2          63802.357345     63802.357345
# 3          58742.869255     58742.869255
# 4           2306.200351      2306.200351
#
# [5 rows x 26 columns]

# %%
characteristics = pd.read_csv("data/trajectory_characteristics.csv", on_bad_lines='skip')
print(len(characteristics))
characteristics = characteristics[characteristics["flight_id"]!="flight_id"]
print(len(characteristics))
characteristics.head()
# Out:
# 510865
# 510865
#    flight_id     max_fuel               first_cruise  first_cruise_alt
# 0  254942095  5786.875688  2022-09-01 17:29:30+00:00           37000.0
# 1  254942148  3516.894652  2022-09-01 17:47:30+00:00           34000.0
# 2  254942098  1848.781798  2022-09-01 17:27:00+00:00           30000.0
# 3  254942161  4449.149948  2022-09-01 17:33:00+00:00           37000.0
# 4  254942068  9767.098354  2022-09-01 17:50:30+00:00           35000.0

# %%
data["takeoff_time"] = pd.to_datetime(data["actual_offblock_time"]) + pd.to_timedelta(data['taxiout_time'], unit='min')
data.iloc[0]
# Out:
# flight_id                                       248763780
# date                                           2022-01-01
# callsign                 3840d84f25d3f5fcc0a1be3076bb4039
# adep                                                 EGLL
# name_adep                                 London Heathrow
# country_code_adep                                      GB
# ades                                                 EICK
# name_ades                                            Cork
# country_code_ades                                      IE
# actual_offblock_time                 2022-01-01T13:46:00Z
# arrival_time                         2022-01-01T15:04:56Z
# aircraft_type                                        A320
# wtc                                                     M
# airline                  a73f82288988b79be490c6322f4c32ed
# flight_duration                                        61
# taxiout_time                                           18
# flown_distance                                        321
# tow                                               54748.0
# dataset                                         challenge
# great_circle_miles                             345.260072
# mtow_fill                                         78000.0
# oew_fill                                          42600.0
# total_fuel                                         2057.0
# replacer                                             A320
# total_fuel_regression                         2079.383478
# total_fuel_fill                                    2057.0
# takeoff_time                    2022-01-01 14:04:00+00:00
# Name: 0, dtype: object

# %%
data["day_of_week"] = pd.to_datetime(data["date"]).dt.dayofweek
data["month"] = pd.to_datetime(data["date"]).dt.month

# %%
plfs = pd.read_csv("data/passenger_load_factors.csv")
plfs= plfs[["month", "lf"]]
plfs
# Out:
#     month    lf
# 0       1  68.2
# 1       2  72.1
# 2       3  73.9
# 3       4  79.5
# 4       5  80.7
# 5       6  86.0
# 6       7  87.0
# 7       8  86.2
# 8       9  84.7
# 9      10  84.8
# 10     11  83.8
# 11     12  83.6

# %%
data = data.merge(plfs, on="month", how="left")

# %%
def get_tz(row): 
    try:
        zone = country_timezones(row["country_code_adep"])[0]
        hour = pd.to_datetime(row["actual_offblock_time"]).to_pydatetime().astimezone(pytz.timezone(zone)).time().hour
        return hour
        #print(hour)
    except: 
        return np.nan

# %%
data["hour_in_local"] = data.progress_apply(lambda x: get_tz(x), axis=1)
data
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 527162/527162 [08:08<00:00, 1078.90it/s]
#         flight_id        date                          callsign  adep  \
# 0       248763780  2022-01-01  3840d84f25d3f5fcc0a1be3076bb4039  EGLL
# 1       248760618  2022-01-01  f6f610e73002b8892a239a81321f7f1d  LEBL
# 2       248753824  2022-01-01  139670936660762c230ca92556ba842b  ESSA
# 3       248753852  2022-01-01  509dc61bb54fbab0e5406067c95603e2  LSZH
# 4       248755934  2022-01-01  d0610d000dcf26b1d7bba8103ecc393d  EIDW
# ...           ...         ...                               ...   ...
# 527157  258068876  2022-12-31  c9fca302ca2e28acab0eb0bb1b46f11b  LTFM
# 527158  258064675  2022-12-31  00f96ad0e382476649574ba044c764fc  EHAM
# 527159  258065436  2022-12-31  87c552b7f6d9bbd16a66e95df761c7f2  LEBL
# 527160  258058138  2022-12-31  2cd57e434494606c965bac87c024bda2  LIPE
# 527161  258058370  2022-12-31  5f0c222c7f7ceff3fbe75c854cce74c9  UBBB
#
#                 name_adep country_code_adep  ades        name_ades  \
# 0         London Heathrow                GB  EICK             Cork
# 1               Barcelona                ES  KMIA            Miami
# 2       Stockholm Arlanda                SE  KORD   Chicago O'Hare
# 3                  Zurich                CH  KPHL     Philadelphia
# 4                  Dublin                IE  EGLL  London Heathrow
# ...                   ...               ...   ...              ...
# 527157       iGA Istanbul                TR  LSZH           Zurich
# 527158          Amsterdam                NL  EDDF        Frankfurt
# 527159          Barcelona                ES  KJFK     New York JFK
# 527160            Bologna                IT  LOWW           Vienna
# 527161               Baku                AZ  LTFM     iGA Istanbul
#
#        country_code_ades  actual_offblock_time  ...  oew_fill total_fuel  \
# 0                     IE  2022-01-01T13:46:00Z  ...   42600.0     2057.0
# 1                     US  2022-01-01T09:55:00Z  ...  138000.0        NaN
# 2                     US  2022-01-01T09:39:00Z  ...  122780.0        NaN
# 3                     US  2022-01-01T11:04:00Z  ...  119000.0        NaN
# 4                     GB  2022-01-01T12:36:00Z  ...   50000.0        NaN
# ...                  ...                   ...  ...       ...        ...
# 527157                CH  2022-12-31T09:25:00Z  ...   48500.0     7685.0
# 527158                DE  2022-12-31T10:04:21Z  ...   42600.0     1501.0
# 527159                US  2022-12-31T09:34:00Z  ...  138000.0        NaN
# 527160                AT  2022-12-31T09:37:00Z  ...   28583.0        NaN
# 527161                TR  2022-12-31T09:40:00Z  ...   41400.0     6161.0
#
#        replacer total_fuel_regression  total_fuel_fill  \
# 0          A320           2079.383478      2057.000000
# 1          A333          70057.306105     70057.306105
# 2          A333          63802.357345     63802.357345
# 3          A332          58742.869255     58742.869255
# 4          A321           2306.200351      2306.200351
# ...         ...                   ...              ...
# 527157     A321           7584.486943      7685.000000
# 527158     A320           1521.043383      1501.000000
# 527159     A333          57391.988977     57391.988977
# 527160     E190           1477.520039      1477.520039
# 527161     B738           6139.858508      6161.000000
#
#                     takeoff_time  day_of_week  month    lf  hour_in_local
# 0      2022-01-01 14:04:00+00:00            5      1  68.2           13.0
# 1      2022-01-01 10:08:00+00:00            5      1  68.2           10.0
# 2      2022-01-01 09:54:00+00:00            5      1  68.2           10.0
# 3      2022-01-01 11:15:00+00:00            5      1  68.2           12.0
# 4      2022-01-01 12:50:00+00:00            5      1  68.2           12.0
# ...                          ...          ...    ...   ...            ...
# 527157 2022-12-31 09:50:00+00:00            5     12  83.6           12.0
# 527158 2022-12-31 10:13:21+00:00            5     12  83.6           11.0
# 527159 2022-12-31 09:48:00+00:00            5     12  83.6           10.0
# 527160 2022-12-31 09:52:00+00:00            5     12  83.6           10.0
# 527161 2022-12-31 09:50:00+00:00            5     12  83.6           13.0
#
# [527162 rows x 31 columns]

# %%
data_trim = data[["flight_id",
                "month",
                "day_of_week",
                "hour_in_local",
                "adep",
                "ades",
                "aircraft_type",
                "replacer",
               "wtc", 
               "airline", 
               "flight_duration",
               "great_circle_miles", 
               "lf", 
               "mtow_fill", 
               "oew_fill", 
               "total_fuel_fill", 
               "tow", 
                "takeoff_time", 
                 "dataset"]]

#"traject_est",

# %%
data_trim
# Out:
#         flight_id  month  day_of_week  hour_in_local  adep  ades  \
# 0       248763780      1            5           13.0  EGLL  EICK
# 1       248760618      1            5           10.0  LEBL  KMIA
# 2       248753824      1            5           10.0  ESSA  KORD
# 3       248753852      1            5           12.0  LSZH  KPHL
# 4       248755934      1            5           12.0  EIDW  EGLL
# ...           ...    ...          ...            ...   ...   ...
# 527157  258068876     12            5           12.0  LTFM  LSZH
# 527158  258064675     12            5           11.0  EHAM  EDDF
# 527159  258065436     12            5           10.0  LEBL  KJFK
# 527160  258058138     12            5           10.0  LIPE  LOWW
# 527161  258058370     12            5           13.0  UBBB  LTFM
#
#        aircraft_type replacer wtc                           airline  \
# 0               A320     A320   M  a73f82288988b79be490c6322f4c32ed
# 1               B772     A333   H  5543e4dc327359ffaf5b9c0e6faaf0e1
# 2               A333     A333   H  8be5c854fd664bcb97fb543339f74770
# 3               B788     A332   H  5543e4dc327359ffaf5b9c0e6faaf0e1
# 4               A21N     A321   M  a73f82288988b79be490c6322f4c32ed
# ...              ...      ...  ..                               ...
# 527157          A321     A321   M  6351ec1b849adacc0cbb3b1313d8d39b
# 527158          A320     A320   M  f502877cab405652cf0dd70c2213e730
# 527159          B772     A333   H  5543e4dc327359ffaf5b9c0e6faaf0e1
# 527160          E195     E190   M  5d407cb11cc29578cc3e292e743f5393
# 527161          B738     B738   M  6351ec1b849adacc0cbb3b1313d8d39b
#
#         flight_duration  great_circle_miles    lf  mtow_fill  oew_fill  \
# 0                    61          345.260072  68.2    78000.0   42600.0
# 1                   570         4688.045888  68.2   297000.0  138000.0
# 2                   554         4260.121521  68.2   242000.0  122780.0
# 3                   497         4013.989694  68.2   228000.0  119000.0
# 4                    55          279.504141  68.2    97000.0   50000.0
# ...                 ...                 ...   ...        ...       ...
# 527157              154         1080.659253  83.6    93500.0   48500.0
# 527158               42          228.208435  83.6    78000.0   42600.0
# 527159              483         3821.564319  83.6   297000.0  138000.0
# 527160               55          352.696423  83.6    50790.0   28583.0
# 527161              158         1112.217472  83.6    79000.0   41400.0
#
#         total_fuel_fill            tow              takeoff_time     dataset
# 0           2057.000000   54748.000000 2022-01-01 14:04:00+00:00   challenge
# 1          70057.306105  185441.000000 2022-01-01 10:08:00+00:00   challenge
# 2          63802.357345  230396.000000 2022-01-01 09:54:00+00:00   challenge
# 3          58742.869255  157615.000000 2022-01-01 11:15:00+00:00   challenge
# 4           2306.200351   70318.447226 2022-01-01 12:50:00+00:00   challenge
# ...                 ...            ...                       ...         ...
# 527157      7685.000000            NaN 2022-12-31 09:50:00+00:00  submission
# 527158      1501.000000            NaN 2022-12-31 10:13:21+00:00  submission
# 527159     57391.988977            NaN 2022-12-31 09:48:00+00:00  submission
# 527160      1477.520039            NaN 2022-12-31 09:52:00+00:00  submission
# 527161      6161.000000            NaN 2022-12-31 09:50:00+00:00  submission
#
# [527162 rows x 19 columns]

# %%
data_trim["flight_id"] = data_trim["flight_id"].astype(str)
characteristics["flight_id"] = characteristics["flight_id"].astype(str)
data_trim = data_trim.merge(characteristics, on="flight_id", how="left")

data_trim
# Out:
# /tmp/ipykernel_821677/3575155925.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_trim["flight_id"] = data_trim["flight_id"].astype(str)
#         flight_id  month  day_of_week  hour_in_local  adep  ades  \
# 0       248763780      1            5           13.0  EGLL  EICK
# 1       248760618      1            5           10.0  LEBL  KMIA
# 2       248753824      1            5           10.0  ESSA  KORD
# 3       248753852      1            5           12.0  LSZH  KPHL
# 4       248755934      1            5           12.0  EIDW  EGLL
# ...           ...    ...          ...            ...   ...   ...
# 527157  258068876     12            5           12.0  LTFM  LSZH
# 527158  258064675     12            5           11.0  EHAM  EDDF
# 527159  258065436     12            5           10.0  LEBL  KJFK
# 527160  258058138     12            5           10.0  LIPE  LOWW
# 527161  258058370     12            5           13.0  UBBB  LTFM
#
#        aircraft_type replacer wtc                           airline  ...  \
# 0               A320     A320   M  a73f82288988b79be490c6322f4c32ed  ...
# 1               B772     A333   H  5543e4dc327359ffaf5b9c0e6faaf0e1  ...
# 2               A333     A333   H  8be5c854fd664bcb97fb543339f74770  ...
# 3               B788     A332   H  5543e4dc327359ffaf5b9c0e6faaf0e1  ...
# 4               A21N     A321   M  a73f82288988b79be490c6322f4c32ed  ...
# ...              ...      ...  ..                               ...  ...
# 527157          A321     A321   M  6351ec1b849adacc0cbb3b1313d8d39b  ...
# 527158          A320     A320   M  f502877cab405652cf0dd70c2213e730  ...
# 527159          B772     A333   H  5543e4dc327359ffaf5b9c0e6faaf0e1  ...
# 527160          E195     E190   M  5d407cb11cc29578cc3e292e743f5393  ...
# 527161          B738     B738   M  6351ec1b849adacc0cbb3b1313d8d39b  ...
#
#           lf  mtow_fill  oew_fill  total_fuel_fill            tow  \
# 0       68.2    78000.0   42600.0      2057.000000   54748.000000
# 1       68.2   297000.0  138000.0     70057.306105  185441.000000
# 2       68.2   242000.0  122780.0     63802.357345  230396.000000
# 3       68.2   228000.0  119000.0     58742.869255  157615.000000
# 4       68.2    97000.0   50000.0      2306.200351   70318.447226
# ...      ...        ...       ...              ...            ...
# 527157  83.6    93500.0   48500.0      7685.000000            NaN
# 527158  83.6    78000.0   42600.0      1501.000000            NaN
# 527159  83.6   297000.0  138000.0     57391.988977            NaN
# 527160  83.6    50790.0   28583.0      1477.520039            NaN
# 527161  83.6    79000.0   41400.0      6161.000000            NaN
#
#                     takeoff_time     dataset      max_fuel  \
# 0      2022-01-01 14:04:00+00:00   challenge   2902.983545
# 1      2022-01-01 10:08:00+00:00   challenge  12681.820334
# 2      2022-01-01 09:54:00+00:00   challenge  16490.600047
# 3      2022-01-01 11:15:00+00:00   challenge  18673.910205
# 4      2022-01-01 12:50:00+00:00   challenge   3319.719170
# ...                          ...         ...           ...
# 527157 2022-12-31 09:50:00+00:00  submission   9500.597411
# 527158 2022-12-31 10:13:21+00:00  submission   3070.692671
# 527159 2022-12-31 09:48:00+00:00  submission  13990.222635
# 527160 2022-12-31 09:52:00+00:00  submission   1791.295075
# 527161 2022-12-31 09:50:00+00:00  submission   1744.979976
#
#                      first_cruise  first_cruise_alt
# 0                             NaN               NaN
# 1       2022-01-01 10:30:00+00:00           33000.0
# 2       2022-01-01 10:25:30+00:00           36000.0
# 3       2022-01-01 11:38:30+00:00           38000.0
# 4       2022-01-01 13:06:30+00:00           33000.0
# ...                           ...               ...
# 527157  2022-12-31 10:14:30+00:00           36000.0
# 527158  2022-12-31 10:29:30+00:00           27000.0
# 527159  2022-12-31 10:10:30+00:00           33000.0
# 527160  2022-12-31 10:12:30+00:00           32000.0
# 527161  2022-12-31 11:37:00+00:00           38000.0
#
# [527162 rows x 22 columns]

# %%
data_trim["time_to_cruise"] = (pd.to_datetime(data_trim["first_cruise"]) - pd.to_datetime(data_trim["takeoff_time"])).dt.seconds
data_trim["alt_per_s"] = data_trim["first_cruise_alt"].astype(float) / data_trim["time_to_cruise"].astype(float)
data_trim = data_trim.drop(columns=["first_cruise", "takeoff_time"])

data_trim["est_load_lf_adjusted"] = (data_trim["mtow_fill"] -  data_trim["oew_fill"] - data_trim["total_fuel_fill"]) * data_trim["lf"] / 100
data_trim["est_tow"] = data_trim["est_load_lf_adjusted"] + data_trim["oew_fill"] + data_trim["total_fuel_fill"]

data_trim
# Out:
#         flight_id  month  day_of_week  hour_in_local  adep  ades  \
# 0       248763780      1            5           13.0  EGLL  EICK
# 1       248760618      1            5           10.0  LEBL  KMIA
# 2       248753824      1            5           10.0  ESSA  KORD
# 3       248753852      1            5           12.0  LSZH  KPHL
# 4       248755934      1            5           12.0  EIDW  EGLL
# ...           ...    ...          ...            ...   ...   ...
# 527157  258068876     12            5           12.0  LTFM  LSZH
# 527158  258064675     12            5           11.0  EHAM  EDDF
# 527159  258065436     12            5           10.0  LEBL  KJFK
# 527160  258058138     12            5           10.0  LIPE  LOWW
# 527161  258058370     12            5           13.0  UBBB  LTFM
#
#        aircraft_type replacer wtc                           airline  ...  \
# 0               A320     A320   M  a73f82288988b79be490c6322f4c32ed  ...
# 1               B772     A333   H  5543e4dc327359ffaf5b9c0e6faaf0e1  ...
# 2               A333     A333   H  8be5c854fd664bcb97fb543339f74770  ...
# 3               B788     A332   H  5543e4dc327359ffaf5b9c0e6faaf0e1  ...
# 4               A21N     A321   M  a73f82288988b79be490c6322f4c32ed  ...
# ...              ...      ...  ..                               ...  ...
# 527157          A321     A321   M  6351ec1b849adacc0cbb3b1313d8d39b  ...
# 527158          A320     A320   M  f502877cab405652cf0dd70c2213e730  ...
# 527159          B772     A333   H  5543e4dc327359ffaf5b9c0e6faaf0e1  ...
# 527160          E195     E190   M  5d407cb11cc29578cc3e292e743f5393  ...
# 527161          B738     B738   M  6351ec1b849adacc0cbb3b1313d8d39b  ...
#
#         oew_fill  total_fuel_fill            tow     dataset      max_fuel  \
# 0        42600.0      2057.000000   54748.000000   challenge   2902.983545
# 1       138000.0     70057.306105  185441.000000   challenge  12681.820334
# 2       122780.0     63802.357345  230396.000000   challenge  16490.600047
# 3       119000.0     58742.869255  157615.000000   challenge  18673.910205
# 4        50000.0      2306.200351   70318.447226   challenge   3319.719170
# ...          ...              ...            ...         ...           ...
# 527157   48500.0      7685.000000            NaN  submission   9500.597411
# 527158   42600.0      1501.000000            NaN  submission   3070.692671
# 527159  138000.0     57391.988977            NaN  submission  13990.222635
# 527160   28583.0      1477.520039            NaN  submission   1791.295075
# 527161   41400.0      6161.000000            NaN  submission   1744.979976
#
#         first_cruise_alt  time_to_cruise  alt_per_s  est_load_lf_adjusted  \
# 0                    NaN             NaN        NaN          22739.926000
# 1                33000.0          1320.0  25.000000          60658.917236
# 2                36000.0          1890.0  19.047619          37794.832291
# 3                38000.0          1410.0  26.950355          34275.363168
# 4                33000.0           990.0  33.333333          30481.171361
# ...                  ...             ...        ...                   ...
# 527157           36000.0          1470.0  24.489796          31195.340000
# 527158           27000.0           969.0  27.863777          28339.564000
# 527159           33000.0          1350.0  24.444444          84944.297215
# 527160           32000.0          1230.0  26.016260          17329.845248
# 527161           38000.0          6420.0   5.919003          26283.004000
#
#               est_tow
# 0        67396.926000
# 1       268716.223341
# 2       224377.189636
# 3       212018.232423
# 4        82787.371712
# ...               ...
# 527157   87380.340000
# 527158   72440.564000
# 527159  280336.286192
# 527160   47390.365286
# 527161   73844.004000
#
# [527162 rows x 24 columns]

# %% [markdown]
# ## Variable types and rounding

# %%
data_trim.iloc[0]
# Out:
# flight_id                                      248763780
# month                                                  1
# day_of_week                                            5
# hour_in_local                                       13.0
# adep                                                EGLL
# ades                                                EICK
# aircraft_type                                       A320
# replacer                                            A320
# wtc                                                    M
# airline                 a73f82288988b79be490c6322f4c32ed
# flight_duration                                       61
# great_circle_miles                            345.260072
# lf                                                  68.2
# mtow_fill                                        78000.0
# oew_fill                                         42600.0
# total_fuel_fill                                   2057.0
# tow                                              54748.0
# dataset                                        challenge
# max_fuel                                     2902.983545
# first_cruise_alt                                     NaN
# time_to_cruise                                       NaN
# alt_per_s                                            NaN
# est_load_lf_adjusted                           22739.926
# est_tow                                        67396.926
# Name: 0, dtype: object

# %%
data_trim["flight_id"] = data_trim["flight_id"].astype(str)
print(len(data_trim[data_trim["flight_id"].isna()]) / len(data_trim["flight_id"]))
# Out:
# 0.0

# %%
data_trim["month"] = data_trim["month"].astype(int)
print(len(data_trim[data_trim["month"].isna()]) / len(data_trim["month"]))
# Out:
# 0.0

# %%
data_trim["day_of_week"] = data_trim["day_of_week"].astype(int)
print(len(data_trim[data_trim["day_of_week"].isna()]) / len(data_trim["day_of_week"]))
# Out:
# 0.0

# %%
data_trim["adep"] = data_trim["adep"].astype(str)
print(len(data_trim[data_trim["adep"].isna()]) / len(data_trim["adep"]))
# Out:
# 0.0

# %%
data_trim["ades"] = data_trim["ades"].astype(str)
print(len(data_trim[data_trim["ades"].isna()]) / len(data_trim["ades"]))
# Out:
# 0.0

# %%
data_trim["aircraft_type"] = data_trim["aircraft_type"].astype(str)
print(len(data_trim[data_trim["aircraft_type"].isna()]) / len(data_trim["aircraft_type"]))
# Out:
# 0.0

# %%
data_trim = data_trim.drop(columns=["wtc"])

# %%
data_trim["airline"] = data_trim["airline"].astype(str)
print(len(data_trim[data_trim["airline"].isna()]) / len(data_trim["airline"]))
# Out:
# 0.0

# %%
data_trim["flight_duration_sec"] = data_trim["flight_duration"].astype(int) * 60
data_trim = data_trim.drop(columns=["flight_duration"])
print(len(data_trim[data_trim["flight_duration_sec"].isna()]) / len(data_trim["flight_duration_sec"]))
# Out:
# 0.0

# %%
data_trim["great_circle_km"] = data_trim["great_circle_miles"] * 1.60934
data_trim["great_circle_km"] = data_trim["great_circle_km"].astype(int)
data_trim = data_trim.drop(columns=["great_circle_miles"])
print(len(data_trim[data_trim["great_circle_km"].isna()]) / len(data_trim["great_circle_km"]))
# Out:
# 0.0

# %%
data_trim = data_trim.drop(columns=["lf"])

# %%
data_trim["mtow_fill"] = data_trim["mtow_fill"].apply(lambda x: round(x, 0)).astype(int)
print(len(data_trim[data_trim["mtow_fill"].isna()]) / len(data_trim["mtow_fill"]))
# Out:
# 0.0

# %%
data_trim["oew_fill"] = data_trim["oew_fill"].apply(lambda x: round(x, 0)).astype(int)
print(len(data_trim[data_trim["oew_fill"].isna()]) / len(data_trim["oew_fill"]))
# Out:
# 0.0

# %%
data_trim["total_fuel_fill"] = data_trim["total_fuel_fill"].apply(lambda x: round(x, 0)).astype(int)
print(len(data_trim[data_trim["total_fuel_fill"].isna()]) / len(data_trim["total_fuel_fill"]))
# Out:
# 0.0

# %%
data_trim["tow"] = data_trim["tow"].apply(lambda x: round(x, 0)).astype(float)
print(len(data_trim[data_trim["tow"].isna()]) / len(data_trim["tow"]))
# Out:
# 0.30000075878003346

# %%
data_trim = data_trim.drop(columns=["max_fuel"])

# %%
data_trim["first_cruise_alt"] = data_trim["first_cruise_alt"].astype(float).apply(lambda x: round(x, 0))
print(1 - (len(data_trim[data_trim["first_cruise_alt"].isna()]) / len(data_trim["first_cruise_alt"])))
# Out:
# 0.8445449406444319

# %%
data_trim["time_to_cruise"] = data_trim["time_to_cruise"].astype(float).apply(lambda x: round(x, 0))
print(1 - (len(data_trim[data_trim["time_to_cruise"].isna()]) / len(data_trim["time_to_cruise"])))
# Out:
# 0.8445449406444319

# %%
data_trim["alt_per_s"] = data_trim["alt_per_s"].astype(float).apply(lambda x: round(x, 1))
print(1 - (len(data_trim[data_trim["alt_per_s"].isna()]) / len(data_trim["alt_per_s"])))
# Out:
# 0.8445449406444319

# %%
data_trim["est_load_lf_adjusted"] = data_trim["est_load_lf_adjusted"].astype(float).apply(lambda x: round(x, 0))
print(1 - (len(data_trim[data_trim["est_load_lf_adjusted"].isna()]) / len(data_trim["est_load_lf_adjusted"])))
# Out:
# 1.0

# %%
data_trim["est_tow"] = data_trim["est_tow"].astype(float).apply(lambda x: round(x, 0))
print(1 - (len(data_trim[data_trim["est_tow"].isna()]) / len(data_trim["est_tow"])))
# Out:
# 1.0

# %%
data_trim
# Out:
#         flight_id  month  day_of_week  hour_in_local  adep  ades  \
# 0       248763780      1            5           13.0  EGLL  EICK
# 1       248760618      1            5           10.0  LEBL  KMIA
# 2       248753824      1            5           10.0  ESSA  KORD
# 3       248753852      1            5           12.0  LSZH  KPHL
# 4       248755934      1            5           12.0  EIDW  EGLL
# ...           ...    ...          ...            ...   ...   ...
# 527157  258068876     12            5           12.0  LTFM  LSZH
# 527158  258064675     12            5           11.0  EHAM  EDDF
# 527159  258065436     12            5           10.0  LEBL  KJFK
# 527160  258058138     12            5           10.0  LIPE  LOWW
# 527161  258058370     12            5           13.0  UBBB  LTFM
#
#        aircraft_type replacer                           airline  mtow_fill  \
# 0               A320     A320  a73f82288988b79be490c6322f4c32ed      78000
# 1               B772     A333  5543e4dc327359ffaf5b9c0e6faaf0e1     297000
# 2               A333     A333  8be5c854fd664bcb97fb543339f74770     242000
# 3               B788     A332  5543e4dc327359ffaf5b9c0e6faaf0e1     228000
# 4               A21N     A321  a73f82288988b79be490c6322f4c32ed      97000
# ...              ...      ...                               ...        ...
# 527157          A321     A321  6351ec1b849adacc0cbb3b1313d8d39b      93500
# 527158          A320     A320  f502877cab405652cf0dd70c2213e730      78000
# 527159          B772     A333  5543e4dc327359ffaf5b9c0e6faaf0e1     297000
# 527160          E195     E190  5d407cb11cc29578cc3e292e743f5393      50790
# 527161          B738     B738  6351ec1b849adacc0cbb3b1313d8d39b      79000
#
#         ...  total_fuel_fill       tow     dataset first_cruise_alt  \
# 0       ...             2057   54748.0   challenge              NaN
# 1       ...            70057  185441.0   challenge          33000.0
# 2       ...            63802  230396.0   challenge          36000.0
# 3       ...            58743  157615.0   challenge          38000.0
# 4       ...             2306   70318.0   challenge          33000.0
# ...     ...              ...       ...         ...              ...
# 527157  ...             7685       NaN  submission          36000.0
# 527158  ...             1501       NaN  submission          27000.0
# 527159  ...            57392       NaN  submission          33000.0
# 527160  ...             1478       NaN  submission          32000.0
# 527161  ...             6161       NaN  submission          38000.0
#
#         time_to_cruise  alt_per_s  est_load_lf_adjusted   est_tow  \
# 0                  NaN        NaN               22740.0   67397.0
# 1               1320.0       25.0               60659.0  268716.0
# 2               1890.0       19.0               37795.0  224377.0
# 3               1410.0       27.0               34275.0  212018.0
# 4                990.0       33.3               30481.0   82787.0
# ...                ...        ...                   ...       ...
# 527157          1470.0       24.5               31195.0   87380.0
# 527158           969.0       27.9               28340.0   72441.0
# 527159          1350.0       24.4               84944.0  280336.0
# 527160          1230.0       26.0               17330.0   47390.0
# 527161          6420.0        5.9               26283.0   73844.0
#
#         flight_duration_sec  great_circle_km
# 0                      3660              555
# 1                     34200             7544
# 2                     33240             6855
# 3                     29820             6459
# 4                      3300              449
# ...                     ...              ...
# 527157                 9240             1739
# 527158                 2520              367
# 527159                28980             6150
# 527160                 3300              567
# 527161                 9480             1789
#
# [527162 rows x 21 columns]

# %%
data_trim[data_trim["dataset"]=="challenge"].to_csv("data/STAGE_1_TRAIN.csv", index=False)

# %%
data_trim.to_csv("data/STAGE_1_ALL.csv", index=False)

# %% [markdown]
# ## Find submission adep and ades values that aren't in training data

# %%
data_trim = pd.read_csv("data/STAGE_1_ALL.csv")

# %%
stage_1_train_data = data_trim[data_trim["dataset"]=="challenge"]
stage_1_train_data
# Out:
#         flight_id  month  day_of_week  hour_in_local  adep  ades  \
# 0       248763780      1            5           13.0  EGLL  EICK
# 1       248760618      1            5           10.0  LEBL  KMIA
# 2       248753824      1            5           10.0  ESSA  KORD
# 3       248753852      1            5           12.0  LSZH  KPHL
# 4       248755934      1            5           12.0  EIDW  EGLL
# ...           ...    ...          ...            ...   ...   ...
# 369008  258058361     12            5           10.0  LFPG  KMIA
# 369009  258071247     12            5           12.0  LTFM  EDDB
# 369010  258059152     12            5           10.0  EDDL  EIDW
# 369011  258072276     12            5           10.0  LFPG  EIDW
# 369012  258069969     12            5           10.0  LEMD  KJFK
#
#        aircraft_type replacer                           airline  mtow_fill  \
# 0               A320     A320  a73f82288988b79be490c6322f4c32ed      78000
# 1               B772     A333  5543e4dc327359ffaf5b9c0e6faaf0e1     297000
# 2               A333     A333  8be5c854fd664bcb97fb543339f74770     242000
# 3               B788     A332  5543e4dc327359ffaf5b9c0e6faaf0e1     228000
# 4               A21N     A321  a73f82288988b79be490c6322f4c32ed      97000
# ...              ...      ...                               ...        ...
# 369008          B788     A332  5543e4dc327359ffaf5b9c0e6faaf0e1     228000
# 369009          A21N     A321  6351ec1b849adacc0cbb3b1313d8d39b      97000
# 369010          A320     A320  a73f82288988b79be490c6322f4c32ed      78000
# 369011          A21N     A321  a73f82288988b79be490c6322f4c32ed      97000
# 369012          B772     A333  5543e4dc327359ffaf5b9c0e6faaf0e1     297000
#
#         ...  total_fuel_fill       tow    dataset first_cruise_alt  \
# 0       ...             2057   54748.0  challenge              NaN
# 1       ...            70057  185441.0  challenge          33000.0
# 2       ...            63802  230396.0  challenge          36000.0
# 3       ...            58743  157615.0  challenge          38000.0
# 4       ...             2306   70318.0  challenge          33000.0
# ...     ...              ...       ...        ...              ...
# 369008  ...            66892  163438.0  challenge          33975.0
# 369009  ...             7364   78707.0  challenge          34000.0
# 369010  ...             3129   62943.0  challenge          36000.0
# 369011  ...             3678   72611.0  challenge          36000.0
# 369012  ...            53856  195373.0  challenge          33000.0
#
#         time_to_cruise  alt_per_s  est_load_lf_adjusted   est_tow  \
# 0                  NaN        NaN               22740.0   67397.0
# 1               1320.0       25.0               60659.0  268716.0
# 2               1890.0       19.0               37795.0  224377.0
# 3               1410.0       27.0               34275.0  212018.0
# 4                990.0       33.3               30481.0   82787.0
# ...                ...        ...                   ...       ...
# 369008          1290.0       26.3               35202.0  221094.0
# 369009          1410.0       24.1               33136.0   90500.0
# 369010          2610.0       13.8               26979.0   72708.0
# 369011          1350.0       26.7               36217.0   89895.0
# 369012          1230.0       26.8               87901.0  279756.0
#
#         flight_duration_sec  great_circle_km
# 0                      3660              555
# 1                     34200             7544
# 2                     33240             6855
# 3                     29820             6459
# 4                      3300              449
# ...                     ...              ...
# 369008                32700             7371
# 369009                 9480             1685
# 369010                 5940              915
# 369011                 5040              784
# 369012                27180             5760
#
# [369013 rows x 21 columns]

# %%
stage_1_train_data = pd.read_csv("data/train_actual.csv")
stage_1_train_data
# Out:
#         flight_id  month  day_of_week  hour_in_local  adep  ades  \
# 0       248763780      1            5           13.0  EGLL  EICK
# 1       248760618      1            5           10.0  LEBL  KMIA
# 2       248753852      1            5           12.0  LSZH  KPHL
# 3       248755934      1            5           12.0  EIDW  EGLL
# 4       248762583      1            5           11.0  ENGM  LEAL
# ...           ...    ...          ...            ...   ...   ...
# 350578  258058361     12            5           10.0  LFPG  KMIA
# 350579  258071247     12            5           12.0  LTFM  EDDB
# 350580  258059152     12            5           10.0  EDDL  EIDW
# 350581  258072276     12            5           10.0  LFPG  EIDW
# 350582  258069969     12            5           10.0  LEMD  KJFK
#
#        aircraft_type replacer                           airline  mtow_fill  \
# 0               A320     A320  a73f82288988b79be490c6322f4c32ed      78000
# 1               B772     A333  5543e4dc327359ffaf5b9c0e6faaf0e1     297000
# 2               B788     A332  5543e4dc327359ffaf5b9c0e6faaf0e1     228000
# 3               A21N     A321  a73f82288988b79be490c6322f4c32ed      97000
# 4               A20N     B738  8be5c854fd664bcb97fb543339f74770      79000
# ...              ...      ...                               ...        ...
# 350578          B788     A332  5543e4dc327359ffaf5b9c0e6faaf0e1     228000
# 350579          A21N     A321  6351ec1b849adacc0cbb3b1313d8d39b      97000
# 350580          A320     A320  a73f82288988b79be490c6322f4c32ed      78000
# 350581          A21N     A321  a73f82288988b79be490c6322f4c32ed      97000
# 350582          B772     A333  5543e4dc327359ffaf5b9c0e6faaf0e1     297000
#
#         ...  total_fuel_fill     tow    dataset first_cruise_alt  \
# 0       ...             2057   54748  challenge              NaN
# 1       ...            70057  185441  challenge          33000.0
# 2       ...            58743  157615  challenge          38000.0
# 3       ...             2306   70318  challenge          33000.0
# 4       ...             8618   57721  challenge          38000.0
# ...     ...              ...     ...        ...              ...
# 350578  ...            66892  163438  challenge          33975.0
# 350579  ...             7364   78707  challenge          34000.0
# 350580  ...             3129   62943  challenge          36000.0
# 350581  ...             3678   72611  challenge          36000.0
# 350582  ...            53856  195373  challenge          33000.0
#
#         time_to_cruise  alt_per_s  est_load_lf_adjusted  est_tow  \
# 0                  NaN        NaN                 22740    67397
# 1               1320.0       25.0                 60659   268716
# 2               1410.0       27.0                 34275   212018
# 3                990.0       33.3                 30481    82787
# 4               1028.0       37.0                 17788    70706
# ...                ...        ...                   ...      ...
# 350578          1290.0       26.3                 35202   221094
# 350579          1410.0       24.1                 33136    90500
# 350580          2610.0       13.8                 26979    72708
# 350581          1350.0       26.7                 36217    89895
# 350582          1230.0       26.8                 87901   279756
#
#         flight_duration_sec  great_circle_km
# 0                      3660              555
# 1                     34200             7544
# 2                     29820             6459
# 3                      3300              449
# 4                     12840             2570
# ...                     ...              ...
# 350578                32700             7371
# 350579                 9480             1685
# 350580                 5940              915
# 350581                 5040              784
# 350582                27180             5760
#
# [350583 rows x 21 columns]

# %%
not_sub = stage_1_train_data
sub = pd.read_csv("/mnt/SMB_share/mark/flight_competition/final_submission_set.csv")

# %%
challenge_set = pd.read_csv("/mnt/SMB_share/mark/flight_competition/challenge_set.csv")
challenge_set
# Out:
#         flight_id        date                          callsign  adep  \
# 0       248763780  2022-01-01  3840d84f25d3f5fcc0a1be3076bb4039  EGLL
# 1       248760618  2022-01-01  f6f610e73002b8892a239a81321f7f1d  LEBL
# 2       248753824  2022-01-01  139670936660762c230ca92556ba842b  ESSA
# 3       248753852  2022-01-01  509dc61bb54fbab0e5406067c95603e2  LSZH
# 4       248755934  2022-01-01  d0610d000dcf26b1d7bba8103ecc393d  EIDW
# ...           ...         ...                               ...   ...
# 369008  258058361  2022-12-31  85ee68e5b7b5acf24ba00d1318eca1e8  LFPG
# 369009  258071247  2022-12-31  570cf7d5ebbd691bcba63e7466607da7  LTFM
# 369010  258059152  2022-12-31  5a7e43e4f981539ae3d3b1cb31591b7c  EDDL
# 369011  258072276  2022-12-31  a1c078516f9f9e90cacec61854cad45b  LFPG
# 369012  258069969  2022-12-31  6c98fcaa191dec632b87b46511f1d2da  LEMD
#
#                       name_adep country_code_adep  ades           name_ades  \
# 0               London Heathrow                GB  EICK                Cork
# 1                     Barcelona                ES  KMIA               Miami
# 2             Stockholm Arlanda                SE  KORD      Chicago O'Hare
# 3                        Zurich                CH  KPHL        Philadelphia
# 4                        Dublin                IE  EGLL     London Heathrow
# ...                         ...               ...   ...                 ...
# 369008  Paris Charles de Gaulle                FR  KMIA               Miami
# 369009             iGA Istanbul                TR  EDDB  Berlin Brandenburg
# 369010               Dusseldorf                DE  EIDW              Dublin
# 369011  Paris Charles de Gaulle                FR  EIDW              Dublin
# 369012           Madrid Barajas                ES  KJFK        New York JFK
#
#        country_code_ades  actual_offblock_time          arrival_time  \
# 0                     IE  2022-01-01T13:46:00Z  2022-01-01T15:04:56Z
# 1                     US  2022-01-01T09:55:00Z  2022-01-01T19:37:56Z
# 2                     US  2022-01-01T09:39:00Z  2022-01-01T19:08:13Z
# 3                     US  2022-01-01T11:04:00Z  2022-01-01T19:32:13Z
# 4                     GB  2022-01-01T12:36:00Z  2022-01-01T13:44:32Z
# ...                  ...                   ...                   ...
# 369008                US  2022-12-31T09:38:00Z  2022-12-31T19:03:48Z
# 369009                DE  2022-12-31T09:27:00Z  2022-12-31T12:29:41Z
# 369010                IE  2022-12-31T09:52:00Z  2022-12-31T11:41:51Z
# 369011                IE  2022-12-31T09:37:00Z  2022-12-31T11:13:10Z
# 369012                US  2022-12-31T09:38:00Z  2022-12-31T17:26:35Z
#
#        aircraft_type wtc                           airline  flight_duration  \
# 0               A320   M  a73f82288988b79be490c6322f4c32ed               61
# 1               B772   H  5543e4dc327359ffaf5b9c0e6faaf0e1              570
# 2               A333   H  8be5c854fd664bcb97fb543339f74770              554
# 3               B788   H  5543e4dc327359ffaf5b9c0e6faaf0e1              497
# 4               A21N   M  a73f82288988b79be490c6322f4c32ed               55
# ...              ...  ..                               ...              ...
# 369008          B788   H  5543e4dc327359ffaf5b9c0e6faaf0e1              545
# 369009          A21N   M  6351ec1b849adacc0cbb3b1313d8d39b              158
# 369010          A320   M  a73f82288988b79be490c6322f4c32ed               99
# 369011          A21N   M  a73f82288988b79be490c6322f4c32ed               84
# 369012          B772   H  5543e4dc327359ffaf5b9c0e6faaf0e1              453
#
#         taxiout_time  flown_distance            tow
# 0                 18             321   54748.000000
# 1                 13            4193  185441.000000
# 2                 15            3770  230396.000000
# 3                 11            3607  157615.000000
# 4                 14             305   70318.447226
# ...              ...             ...            ...
# 369008            21            4046  163438.000000
# 369009            25             946   78707.000000
# 369010            11             522   62942.750000
# 369011            12             466   72611.161024
# 369012            16            3213  195373.000000
#
# [369013 rows x 18 columns]

# %%
missing_adep = sub[~sub["adep"].isin(not_sub["adep"].unique())]["adep"].unique()
missing_ades = sub[~sub["ades"].isin(not_sub["ades"].unique())]["ades"].unique()

# %%
print(len(sub[sub["adep"]=="VAJJ"]))
print(len(challenge_set[challenge_set["adep"]=="VAJJ"]))
# Out:
# 0
# 0

# %%
# missing_adep = ["7FL6", "CYAW", "DAOL", "EDBA", "EDTB", "EG73", "EGJB", "EGVA", "ENKA", "EPKM", ...11 not listed..., "LTBW", "MMEP", "OS66", "RJAK", "RJTK", "UDYE", "UGEJ", "UKOM", "VAJJ", "WICB"]
# missing_ades = ["7FL6", "CYAW", "DAOL", "EDBA", "EDMT", "EDTB", "EG73", "EGJB", "EGVA", "EPKM", ...7 not listed..., "LTAQ", "LTCO", "OS66", "RJAK", "UDYE", "UGEJ", "UKOM", "VAJJ", "VHSK", "WICB"]
missing = np.concatenate((missing_adep, missing_ades), axis=None)
missing = list(set(missing))
missing = missing + ["HRYR"] + ["LTAW", "LTCN", "LTCO", "LTCT", "RKSI", "RPLL", "WADD"] + ["HTZA"] + ["LTCP", "LTCW", "VVTS", "WMKK", "ZMCK"] + ["VTBS"] + ["HTDA", "LTCL", "VTSG"] + ["HAAB", "HCMM", "LTCV"]

missing
# Out:
# ['EGPE',
#  'EDSB',
#  'UBBN',
#  'LTAP',
#  'LKTB',
#  'WIII',
#  'EDDE',
#  'RJAA',
#  'VABB',
#  'LTAJ',
#  'LTCI',
#  'LTBU',
#  'LEAB',
#  'RJTT',
#  'UKOO',
#  'KDAB',
#  'LFLX',
#  'KRFD',
#  'VHHH',
#  'OMAA',
#  'EFET',
#  'LIPO',
#  'LGBL',
#  'UDYZ',
#  'EDJA',
#  'EPKT',
#  'HHAS',
#  'DAOO',
#  'LTCM',
#  'CYHZ',
#  'LKMT',
#  'HUEN',
#  'LFBH',
#  'EGJJ',
#  'ESKN',
#  'EGVN',
#  'MMPR',
#  'HRYR',
#  'LTAW',
#  'LTCN',
#  'LTCO',
#  'LTCT',
#  'RKSI',
#  'RPLL',
#  'WADD',
#  'HTZA',
#  'LTCP',
#  'LTCW',
#  'VVTS',
#  'WMKK',
#  'ZMCK',
#  'VTBS',
#  'HTDA',
#  'LTCL',
#  'VTSG',
#  'HAAB',
#  'HCMM',
#  'LTCV']

# %%
manual_airports = {
'LTCU':{'icao': 'LTCU',
 'lat': 38.85858736260065,
 'lon': 40.59067139686379 
}, 
'LEIB':{'icao': 'LEIB',
 'lat': 38.87392171890811,
 'lon': 1.3722346680281414 
}, 
'DTNH':{'icao': 'DTNH',
 'lat': 36.0834437013865,
 'lon': 10.438704017504692 
}, 
'ESKS':{'icao': 'ESKS',
 'lat': 61.156101445931895,
 'lon': 12.837457063067493 
}, 
'EBCI':{'icao': 'EBCI',
 'lat': 50.463130022524915,
 'lon': 4.462079975151949 
}, 
'EBMB':{'icao': 'EBMB',
 'lat': 50.9154369162626,
 'lon': 4.493584452729591 
}, 
'LTCV':{'icao': 'LTCV',
 'lat': 37.36158697994315,
 'lon': 42.05553763068404
}, 
'OKBK':{'icao': 'OKBK',
 'lat': 37.36160005163285,
 'lon': 42.055506593027715 
}, 
'EGHH':{'icao': 'EGHH',
 'lat': 50.78100421147004,
 'lon': -1.8409717739922666 
}, 
'EGLL':{'icao': 'EGLL',
 'lat': 51.46794534067239,
 'lon': -0.45500243490457304 
}, 
'EKCH':{'icao': 'EKCH',
 'lat': 55.60955846679605,
 'lon': 12.63561794162437 
}, 
'LTFJ':{'icao': 'LTFJ',
 'lat': 40.90849582099669,
 'lon': 29.315195387558404 
}, 
'UTFF':{'icao': 'UTFF',
 'lat': 40.37598329652268,
 'lon': 71.75202477850446 
}, 
'EDDV':{'icao': 'EDDV',
 'lat': 52.462666312589754,
 'lon': 9.684258394471607
}, 
'EBBR':{'icao': 'EBBR',
 'lat': 50.90019751841645,
 'lon': 4.486028487284325
}, 
'EGCN':{'icao': 'EGCN',
 'lat': 53.39443776608614,
 'lon': -1.3842738109711732
}, 
'EGCC':{'icao': 'EGCC',
 'lat': 53.35534409298594,
 'lon':  -2.2771244490697478
}, 
'EGBB':{'icao': 'EGBB',
 'lat': 52.45236082325583,
 'lon': -1.7435028355783422
}, 
'EGKK':{'icao': 'EGKK',
 'lat': 51.15364864102023,
 'lon': -0.18207899325080945
}, 
'EKYT':{'icao': 'EKYT',
 'lat': 57.095703276939744,
 'lon': 9.855358741769924
}, 
'LTAC':{'icao': 'LTAC',
 'lat': 40.11496213059108,
 'lon': 32.99271320586336
}, 
'EHAM':{'icao': 'EHAM',
 'lat': 52.31690578306712,
 'lon': 4.74592996442235
}, 
'EGSY':{'icao': 'EGSY',
 'lat': 53.39926177010993,
 'lon': -1.3841440642047664
}, 
'LTFM':{'icao': 'LTFM',
 'lat': 41.275238322317286,
 'lon': 28.732290831634593
}}

# %%
airports = airportsdata.load()
airports.update(manual_airports)

# %%
for x in missing: 
    try: 
        found = airports[x]
    except: 
        print(x)

# %%
airport_df = pd.DataFrame([[x, airports[x]["lat"], airports[x]["lon"]] for x in airports.keys()], columns=["icao", "lat", "lng"])
airport_gdf = gpd.GeoDataFrame(airport_df, geometry=gpd.points_from_xy(airport_df["lng"], airport_df["lat"]), crs=4326)
airport_gdf
# Out:
#        icao        lat         lng                     geometry
# 0      00AA  38.704020 -101.473910  POINT (-101.47391 38.70402)
# 1      00AK  59.948890 -151.692220  POINT (-151.69222 59.94889)
# 2      00AL  34.864810  -86.770280   POINT (-86.77028 34.86481)
# 3      00AN  59.093470 -156.455830  POINT (-156.45583 59.09347)
# 4      00AR  38.969650  -97.601560   POINT (-97.60156 38.96965)
# ...     ...        ...         ...                          ...
# 28229  _KBH  -3.791670   32.646670    POINT (32.64667 -3.79167)
# 28230  _OUK  60.425580   -0.746600    POINT (-0.74660 60.42558)
# 28231  _YEH  38.481900  106.009000   POINT (106.00900 38.48190)
# 28232  OKBK  37.361600   42.055507    POINT (42.05551 37.36160)
# 28233  EGSY  53.399262   -1.384144    POINT (-1.38414 53.39926)
#
# [28234 rows x 4 columns]

# %%
missing_gpd = airport_gdf[airport_gdf["icao"].isin(missing)]
not_missing = np.concatenate((challenge_set["adep"].unique(), challenge_set["ades"].unique()), axis=None)
not_missing_gpd = airport_gdf[(airport_gdf["icao"].isin(not_missing)) & (~airport_gdf["icao"].isin(missing))]

# %%
pts3 = not_missing_gpd.geometry.unary_union
def near(point, pts=pts3):
     # find the nearest point and return the corresponding Place value
     nearest = not_missing_gpd.geometry == nearest_points(point, pts)[1]
     return not_missing_gpd[nearest].icao.iloc[0]
    
missing_gpd['nearest'] = missing_gpd.apply(lambda row: near(row.geometry), axis=1)
missing_gpd
# Out:
# /home/mark/anaconda3/envs/traffic/lib/python3.10/site-packages/geopandas/geodataframe.py:1528: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#        icao        lat         lng                     geometry nearest
# 6019   CYHZ  44.880800  -63.508600   POINT (-63.50860 44.88080)    KBOS
# 6336   DAOO  35.623900   -0.621180    POINT (-0.62118 35.62390)    GMFO
# 6661   EDDE  50.979800   10.958100    POINT (10.95810 50.97980)    EDDP
# 6744   EDJA  47.988800   10.239500    POINT (10.23950 47.98880)    EDNY
# 6916   EDSB  48.779400    8.080500     POINT (8.08050 48.77940)    LFST
# 7038   EFET  68.362600   23.424300    POINT (23.42430 68.36260)    EFKT
# 7231   EGJJ  49.207900   -2.195510    POINT (-2.19551 49.20790)    EGHH
# 7289   EGPE  57.542500   -4.047500    POINT (-4.04750 57.54250)    EGPF
# 7354   EGVN  51.750000   -1.583620    POINT (-1.58362 51.75000)    EGBB
# 7621   EPKT  50.474300   19.080000    POINT (19.08000 50.47430)    EPKK
# 7723   ESKN  58.788600   16.912200    POINT (16.91220 58.78860)    ESSP
# 9534   HAAB   8.977890   38.799300     POINT (38.79930 8.97789)    HSSK
# 9590   HCMM   2.014440   45.304700     POINT (45.30470 2.01444)    HSSK
# 9641   HHAS  15.291900   38.910700    POINT (38.91070 15.29190)    HSSK
# 9752   HRYR  -1.968630   30.139500    POINT (30.13950 -1.96863)    FZAA
# 9811   HTDA  -6.878110   39.202600    POINT (39.20260 -6.87811)    FAOR
# 9863   HTZA  -6.222020   39.224900    POINT (39.22490 -6.22202)    FAOR
# 9866   HUEN   0.042390   32.443500     POINT (32.44350 0.04239)    HSSK
# 12244  KDAB  29.179910  -81.058040   POINT (-81.05804 29.17991)    KMCO
# 14071  KRFD  42.195360  -89.097220   POINT (-89.09722 42.19536)    KORD
# 14978  LEAB  38.948500   -1.863520    POINT (-1.86352 38.94850)    LEMI
# 15120  LFBH  46.179200   -1.195280    POINT (-1.19528 46.17920)    LFRS
# 15353  LFLX  46.862200    1.730670     POINT (1.73067 46.86220)    LFPO
# 15561  LGBL  39.219600   22.794300    POINT (22.79430 39.21960)    LGSK
# 15743  LIPO  45.428900   10.330600    POINT (10.33060 45.42890)    LIPX
# 15840  LKMT  49.696300   18.111100    POINT (18.11110 49.69630)    EPKK
# 15870  LKTB  49.151300   16.694400    POINT (16.69440 49.15130)    LOWW
# 16180  LTAJ  36.947200   37.478700    POINT (37.47870 36.94720)    LTDA
# 16185  LTAP  40.829400   35.522000    POINT (35.52200 40.82940)    LTFH
# 16192  LTAW  40.307430   36.367410    POINT (36.36741 40.30743)    LTAR
# 16214  LTBU  41.138200   27.919100    POINT (27.91910 41.13820)    LTFM
# 16228  LTCI  38.468200   43.332300    POINT (43.33230 38.46820)    OKBK
# 16231  LTCL  37.978900   41.840400    POINT (41.84040 37.97890)    OKBK
# 16232  LTCM  42.015800   35.066400    POINT (35.06640 42.01580)    LTAL
# 16233  LTCN  37.538830   36.953520    POINT (36.95352 37.53883)    LTDA
# 16234  LTCO  39.654540   43.025980    POINT (43.02598 39.65454)    LTCF
# 16235  LTCP  37.731400   38.468900    POINT (38.46890 37.73140)    LTCS
# 16238  LTCT  39.976630   43.876650    POINT (43.87665 39.97663)    LTCF
# 16240  LTCV  37.361587   42.055538    POINT (42.05554 37.36159)    OKBK
# 16241  LTCW  37.549670   44.237500    POINT (44.23750 37.54967)    ORER
# 16771  MMPR  20.680100 -105.254000  POINT (-105.25400 20.68010)    KIAH
# 18543  OMAA  24.433000   54.651100    POINT (54.65110 24.43300)    OMDW
# 19203  RJAA  35.764700  140.386000   POINT (140.38600 35.76470)    VTSP
# 19312  RJTT  35.552300  139.780000   POINT (139.78000 35.55230)    VTSP
# 19379  RKSI  37.469100  126.451000   POINT (126.45100 37.46910)    VGHS
# 19421  RPLL  14.508600  121.020000   POINT (121.02000 14.50860)    VTSP
# 24485  UBBN  39.188800   45.458400    POINT (45.45840 39.18880)    UBBG
# 24499  UDYZ  40.147300   44.395900    POINT (44.39590 40.14730)    LTCF
# 24660  UKOO  46.426800   30.676500    POINT (30.67650 46.42680)    LUKK
# 25086  VABB  19.088700   72.867900    POINT (72.86790 19.08870)    VOGO
# 25257  VHHH  22.308900  113.915000   POINT (113.91500 22.30890)    VTSP
# 25489  VTBS  13.681100  100.747000   POINT (100.74700 13.68110)    VTSP
# 25522  VTSG   8.099120   98.986200     POINT (98.98620 8.09912)    VTSP
# 25570  VVTS  10.818800  106.652000   POINT (106.65200 10.81880)    VTSP
# 25717  WADD  -8.748170  115.167000   POINT (115.16700 -8.74817)    VTSP
# 25971  WIII  -6.125570  106.656000   POINT (106.65600 -6.12557)    VTSP
# 26051  WMKK   2.745580  101.710000    POINT (101.71000 2.74558)    VTSP
# 28087  ZMCK  47.646670  106.820000   POINT (106.82000 47.64667)    VGHS

# %%
with_replacement = data_trim.copy()
for icao in missing_gpd["icao"].unique(): 
    print(icao) 
    replacer = missing_gpd[missing_gpd["icao"]==icao]["nearest"].iloc[0]
    print(replacer)
    with_replacement["adep"] = with_replacement["adep"].replace(icao, replacer)
    with_replacement["ades"] = with_replacement["ades"].replace(icao, replacer)
# Out:
# CYHZ
# KBOS
# DAOO
# GMFO
# EDDE
# EDDP
# EDJA
# EDNY
# EDSB
# LFST
# EFET
# EFKT
# EGJJ
# EGHH
# EGPE
# EGPF
# EGVN
# EGBB
# EPKT
# EPKK
# ESKN
# ESSP
# HAAB
# HSSK
# HCMM
# HSSK
# HHAS
# HSSK
# HRYR
# FZAA
# HTDA
# FAOR
# HTZA
# FAOR
# HUEN
# HSSK
# KDAB
# KMCO
# KRFD
# KORD
# LEAB
# LEMI
# LFBH
# LFRS
# LFLX
# LFPO
# LGBL
# LGSK
# LIPO
# LIPX
# LKMT
# EPKK
# LKTB
# LOWW
# LTAJ
# LTDA
# LTAP
# LTFH
# LTAW
# LTAR
# LTBU
# LTFM
# LTCI
# OKBK
# LTCL
# OKBK
# LTCM
# LTAL
# LTCN
# LTDA
# LTCO
# LTCF
# LTCP
# LTCS
# LTCT
# LTCF
# LTCV
# OKBK
# LTCW
# ORER
# MMPR
# KIAH
# OMAA
# OMDW
# RJAA
# VTSP
# RJTT
# VTSP
# RKSI
# VGHS
# RPLL
# VTSP
# UBBN
# UBBG
# UDYZ
# LTCF
# UKOO
# LUKK
# VABB
# VOGO
# VHHH
# VTSP
# VTBS
# VTSP
# VTSG
# VTSP
# VVTS
# VTSP
# WADD
# VTSP
# WIII
# VTSP
# WMKK
# VTSP
# ZMCK
# VGHS

# %%
with_replacement.to_csv("data/STAGE_1_ALL_rep.csv", index=False)
